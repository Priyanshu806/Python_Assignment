# %% [markdown]
# # Data Toolkit - Theory Notes (Questions 1–22)

# %% [markdown]
# ## 1. What is NumPy, and why is it widely used in Python?
#
# ### Answer

# %% [markdown]
# a) NumPy is a numerical computing library.
#
# b) Provides fast multidimensional arrays.
#
# c) Used in Data Science, ML and scientific computing.

# %%
import numpy as np
arr=np.array([1,2,3])
print(arr)

# %% [markdown]
# ## 2. How does broadcasting work in NumPy?
#
# ### Answer

# %% [markdown]
# a) Broadcasting performs operations on arrays of different shapes.
#
# b) Smaller arrays are automatically expanded.

# %%
import numpy as np
print(np.array([1,2,3])+5)

# %% [markdown]
# ## 3. What is a Pandas DataFrame?
#
# ### Answer

# %% [markdown]
# a) A DataFrame is a 2D tabular data structure.
#
# b) Rows and columns have labels.

# %%
import pandas as pd
print(pd.DataFrame({'A':[1,2],'B':[3,4]}))

# %% [markdown]
# ## 4. Explain the use of groupby() in Pandas.
#
# ### Answer

# %% [markdown]
# a) groupby() groups data based on one or more columns.
#
# b) Used for aggregation and analysis.

# %% [markdown]
# ## 5. Why is Seaborn preferred for statistical visualizations?
#
# ### Answer

# %% [markdown]
# a) Built on Matplotlib.
#
# b) Provides attractive statistical plots with less code.

# %% [markdown]
# ## 6. NumPy arrays vs Python lists?
#
# ### Answer

# %% [markdown]
# a) Arrays are faster and memory efficient.
#
# b) Arrays support vectorized operations.

# %% [markdown]
# ## 7. What is a heatmap?
#
# ### Answer

# %% [markdown]
# a) A heatmap visualizes values using colors.
#
# b) Commonly used for correlation matrices.

# %% [markdown]
# ## 8. What is vectorized operation?
#
# ### Answer

# %% [markdown]
# a) Operations performed on whole arrays without loops.
#
# b) Improves speed.

# %% [markdown]
# ## 9. Matplotlib vs Plotly?
#
# ### Answer

# %% [markdown]
# a) Matplotlib creates static plots.
#
# b) Plotly creates interactive plots.

# %% [markdown]
# ## 10. Hierarchical indexing in Pandas?
#
# ### Answer

# %% [markdown]
# a) Allows multiple index levels.
#
# b) Useful for complex datasets.

# %% [markdown]
# ## 11. Role of pairplot()?
#
# ### Answer

# %% [markdown]
# a) Shows pairwise relationships among variables.

# %% [markdown]
# ## 12. Purpose of describe()?
#
# ### Answer

# %% [markdown]
# a) Generates summary statistics like mean, std, min and max.

# %% [markdown]
# ## 13. Why handle missing data?
#
# ### Answer

# %% [markdown]
# a) Improves data quality and model accuracy.

# %% [markdown]
# ## 14. Benefits of Plotly?
#
# ### Answer

# %% [markdown]
# a) Interactive, zoomable and web-friendly visualizations.

# %% [markdown]
# ## 15. How NumPy handles multidimensional arrays?
#
# ### Answer

# %% [markdown]
# a) Uses ndarray supporting 1D, 2D and nD arrays.

# %% [markdown]
# ## 16. Role of Bokeh?
#
# ### Answer

# %% [markdown]
# a) Creates interactive web visualizations.

# %% [markdown]
# ## 17. Difference between apply() and map()?
#
# ### Answer

# %% [markdown]
# a) map() works element-wise on Series.
#
# b) apply() works on Series and DataFrames.

# %% [markdown]
# ## 18. Advanced features of NumPy?
#
# ### Answer

# %% [markdown]
# a) Broadcasting
#
# b) Linear algebra
#
# c) Random module
#
# d) FFT
#
# e) Masked arrays

# %% [markdown]
# ## 19. How Pandas simplifies time series?
#
# ### Answer

# %% [markdown]
# a) Supports datetime indexing, resampling and rolling windows.

# %% [markdown]
# ## 20. Role of pivot_table()?
#
# ### Answer

# %% [markdown]
# a) Summarizes data in table format using aggregation.

# %% [markdown]
# ## 21. Why NumPy slicing is faster?
#
# ### Answer

# %% [markdown]
# a) Returns views instead of copies whenever possible.

# %% [markdown]
# ## 22. Common use cases of Seaborn?
#
# ### Answer

# %% [markdown]
# a) Distribution plots
#
# b) Heatmaps
#
# c) Pairplots
#
# d) Regression plots
#
# e) Categorical plots
