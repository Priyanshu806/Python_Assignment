# %% [markdown]
# # Data Types & Structures - Practical Questions (1–30)
#
# Each practical contains the problem, Python program, sample output, and explanation.

# %% [markdown]
# ## 1. Create a string with your name and print it.
#
# ### Problem Statement
# 1. Create a string with your name and print it.

# %%
name='Priyanshu'
print(name)

# %% [markdown]
# ### Sample Output
# ```
# Priyanshu
# ```

# %% [markdown]
# ### Explanation
# a) Creates a string variable.
#
# b) print() displays the value.

# %% [markdown]
# ## 2. Find length of 'Hello World'.
#
# ### Problem Statement
# 2. Find length of 'Hello World'.

# %%
text='Hello World'
print(len(text))

# %% [markdown]
# ### Sample Output
# ```
# 11
# ```

# %% [markdown]
# ### Explanation
# a) len() returns the number of characters.

# %% [markdown]
# ## 3. Slice first 3 characters.
#
# ### Problem Statement
# 3. Slice first 3 characters.

# %%
text='Python Programming'
print(text[:3])

# %% [markdown]
# ### Sample Output
# ```
# Pyt
# ```

# %% [markdown]
# ### Explanation
# a) Slicing returns characters from index 0 to 2.

# %% [markdown]
# ## 4. Convert 'hello' to uppercase.
#
# ### Problem Statement
# 4. Convert 'hello' to uppercase.

# %%
text='hello'
print(text.upper())

# %% [markdown]
# ### Sample Output
# ```
# HELLO
# ```

# %% [markdown]
# ### Explanation
# a) upper() converts to uppercase.

# %% [markdown]
# ## 5. Replace 'apple' with 'orange'.
#
# ### Problem Statement
# 5. Replace 'apple' with 'orange'.

# %%
text='I like apple'
print(text.replace('apple','orange'))

# %% [markdown]
# ### Sample Output
# ```
# I like orange
# ```

# %% [markdown]
# ### Explanation
# a) replace() replaces a substring.

# %% [markdown]
# ## 6. Create list 1 to 5.
#
# ### Problem Statement
# 6. Create list 1 to 5.

# %%
lst=[1,2,3,4,5]
print(lst)

# %% [markdown]
# ### Sample Output
# ```
# [1, 2, 3, 4, 5]
# ```

# %% [markdown]
# ### Explanation
# a) Creates a list.

# %% [markdown]
# ## 7. Append 10.
#
# ### Problem Statement
# 7. Append 10.

# %%
lst=[1,2,3,4]
lst.append(10)
print(lst)

# %% [markdown]
# ### Sample Output
# ```
# [1, 2, 3, 4, 10]
# ```

# %% [markdown]
# ### Explanation
# a) append() adds an element.

# %% [markdown]
# ## 8. Remove number 3.
#
# ### Problem Statement
# 8. Remove number 3.

# %%
lst=[1,2,3,4,5]
lst.remove(3)
print(lst)

# %% [markdown]
# ### Sample Output
# ```
# [1, 2, 4, 5]
# ```

# %% [markdown]
# ### Explanation
# a) remove() deletes the value.

# %% [markdown]
# ## 9. Access second element.
#
# ### Problem Statement
# 9. Access second element.

# %%
lst=['a','b','c','d']
print(lst[1])

# %% [markdown]
# ### Sample Output
# ```
# b
# ```

# %% [markdown]
# ### Explanation
# a) Index 1 is the second element.

# %% [markdown]
# ## 10. Reverse list.
#
# ### Problem Statement
# 10. Reverse list.

# %%
lst=[10,20,30,40,50]
lst.reverse()
print(lst)

# %% [markdown]
# ### Sample Output
# ```
# [50, 40, 30, 20, 10]
# ```

# %% [markdown]
# ### Explanation
# a) reverse() reverses in place.

# %% [markdown]
# ## 11. Create tuple.
#
# ### Problem Statement
# 11. Create tuple.

# %%
t=(100,200,300)
print(t)

# %% [markdown]
# ### Sample Output
# ```
# (100, 200, 300)
# ```

# %% [markdown]
# ### Explanation
# a) Creates a tuple.

# %% [markdown]
# ## 12. Access second-last tuple element.
#
# ### Problem Statement
# 12. Access second-last tuple element.

# %%
t=('red','green','blue','yellow')
print(t[-2])

# %% [markdown]
# ### Sample Output
# ```
# blue
# ```

# %% [markdown]
# ### Explanation
# a) -2 accesses second-last element.

# %% [markdown]
# ## 13. Minimum in tuple.
#
# ### Problem Statement
# 13. Minimum in tuple.

# %%
t=(10,20,5,15)
print(min(t))

# %% [markdown]
# ### Sample Output
# ```
# 5
# ```

# %% [markdown]
# ### Explanation
# a) min() returns smallest value.

# %% [markdown]
# ## 14. Find index of 'cat'.
#
# ### Problem Statement
# 14. Find index of 'cat'.

# %%
t=('dog','cat','rabbit')
print(t.index('cat'))

# %% [markdown]
# ### Sample Output
# ```
# 1
# ```

# %% [markdown]
# ### Explanation
# a) index() returns the position.

# %% [markdown]
# ## 15. Fruit tuple membership.
#
# ### Problem Statement
# 15. Fruit tuple membership.

# %%
t=('apple','banana','mango')
print('kiwi' in t)

# %% [markdown]
# ### Sample Output
# ```
# False
# ```

# %% [markdown]
# ### Explanation
# a) in checks membership.

# %% [markdown]
# ## 16. Create set.
#
# ### Problem Statement
# 16. Create set.

# %%
s={'a','b','c'}
print(s)

# %% [markdown]
# ### Sample Output
# ```
# {'a', 'b', 'c'}
# ```

# %% [markdown]
# ### Explanation
# a) Creates a set.

# %% [markdown]
# ## 17. Clear set.
#
# ### Problem Statement
# 17. Clear set.

# %%
s={1,2,3,4,5}
s.clear()
print(s)

# %% [markdown]
# ### Sample Output
# ```
# set()
# ```

# %% [markdown]
# ### Explanation
# a) clear() removes all elements.

# %% [markdown]
# ## 18. Remove element 4.
#
# ### Problem Statement
# 18. Remove element 4.

# %%
s={1,2,3,4}
s.remove(4)
print(s)

# %% [markdown]
# ### Sample Output
# ```
# {1, 2, 3}
# ```

# %% [markdown]
# ### Explanation
# a) remove() deletes an element.

# %% [markdown]
# ## 19. Union of sets.
#
# ### Problem Statement
# 19. Union of sets.

# %%
a={1,2,3}
b={3,4,5}
print(a|b)

# %% [markdown]
# ### Sample Output
# ```
# {1, 2, 3, 4, 5}
# ```

# %% [markdown]
# ### Explanation
# a) | computes union.

# %% [markdown]
# ## 20. Intersection of sets.
#
# ### Problem Statement
# 20. Intersection of sets.

# %%
a={1,2,3}
b={2,3,4}
print(a&b)

# %% [markdown]
# ### Sample Output
# ```
# {2, 3}
# ```

# %% [markdown]
# ### Explanation
# a) & computes intersection.

# %% [markdown]
# ## 21. Create dictionary.
#
# ### Problem Statement
# 21. Create dictionary.

# %%
d={'name':'John','age':25,'city':'New York'}
print(d)

# %% [markdown]
# ### Sample Output
# ```
# {'name': 'John', 'age': 25, 'city': 'New York'}
# ```

# %% [markdown]
# ### Explanation
# a) Dictionary stores key-value pairs.

# %% [markdown]
# ## 22. Add key-value pair.
#
# ### Problem Statement
# 22. Add key-value pair.

# %%
d={'name':'John','age':25}
d['country']='USA'
print(d)

# %% [markdown]
# ### Sample Output
# ```
# {'name': 'John', 'age': 25, 'country': 'USA'}
# ```

# %% [markdown]
# ### Explanation
# a) Adds a new key.

# %% [markdown]
# ## 23. Access dictionary value.
#
# ### Problem Statement
# 23. Access dictionary value.

# %%
d={'name':'Alice','age':30}
print(d['name'])

# %% [markdown]
# ### Sample Output
# ```
# Alice
# ```

# %% [markdown]
# ### Explanation
# a) Access using key.

# %% [markdown]
# ## 24. Remove key.
#
# ### Problem Statement
# 24. Remove key.

# %%
d={'name':'Bob','age':22,'city':'New York'}
d.pop('age')
print(d)

# %% [markdown]
# ### Sample Output
# ```
# {'name': 'Bob', 'city': 'New York'}
# ```

# %% [markdown]
# ### Explanation
# a) pop() removes a key.

# %% [markdown]
# ## 25. Check key exists.
#
# ### Problem Statement
# 25. Check key exists.

# %%
d={'name':'Alice','city':'Paris'}
print('city' in d)

# %% [markdown]
# ### Sample Output
# ```
# True
# ```

# %% [markdown]
# ### Explanation
# a) in checks keys.

# %% [markdown]
# ## 26. Create list, tuple and dictionary.
#
# ### Problem Statement
# 26. Create list, tuple and dictionary.

# %%
lst=[1,2]
t=(3,4)
d={'a':1}
print(lst,t,d)

# %% [markdown]
# ### Sample Output
# ```
# Depends
# ```

# %% [markdown]
# ### Explanation
# a) Creates three data structures.

# %% [markdown]
# ## 27. Random list and sort.
#
# ### Problem Statement
# 27. Random list and sort.

# %%
import random
lst=[random.randint(1,100) for _ in range(5)]
lst.sort()
print(lst)

# %% [markdown]
# ### Sample Output
# ```
# Random sorted list
# ```

# %% [markdown]
# ### Explanation
# a) Generates and sorts random numbers.

# %% [markdown]
# ## 28. Print third index.
#
# ### Problem Statement
# 28. Print third index.

# %%
lst=['a','b','c','d','e']
print(lst[3])

# %% [markdown]
# ### Sample Output
# ```
# d
# ```

# %% [markdown]
# ### Explanation
# a) Index 3 is the fourth element.

# %% [markdown]
# ## 29. Combine dictionaries.
#
# ### Problem Statement
# 29. Combine dictionaries.

# %%
d1={'a':1}
d2={'b':2}
d1.update(d2)
print(d1)

# %% [markdown]
# ### Sample Output
# ```
# {'a': 1, 'b': 2}
# ```

# %% [markdown]
# ### Explanation
# a) update() merges dictionaries.

# %% [markdown]
# ## 30. Convert list to set.
#
# ### Problem Statement
# 30. Convert list to set.

# %%
lst=['a','b','a','c']
print(set(lst))

# %% [markdown]
# ### Sample Output
# ```
# {'a', 'b', 'c'}
# ```

# %% [markdown]
# ### Explanation
# a) set() removes duplicates.
